# %% [markdown]
# # 🛡️ Cybersecurity Master Roadmap — Beginner to All-Domain Practitioner
# ### *Hinglish Guide | Personal Interactive Notebook*
#
# This notebook is your **single source of truth** for the entire journey — every stage from your original roadmap document is included, nothing dropped, including the topics marked *Already Completed* and *In Progress* (kept in for revision, tracking, and because "completed" doesn't mean "mastered forever" in security).
#
# **How to use this notebook:**
# 1. Read each stage's topic table — it has the **topic**, the **recommended YouTube source**, an **estimated time**, and a **Status** column.
# 2. As you progress, manually update the **Status** column text in the markdown table (⬜ Not Started → 🟡 In Progress → ✅ Completed) — just double-click the markdown cell to edit it.
# 3. Revisit the **Certification Checkpoints** and **Reality Check** sections — they tell you exactly when to sit which exam.
# 4. This is a *living document* — edit the tables directly as you progress; save the notebook regularly.
#
# > ⚠️ **Note on sources:** For topics you (or your friend) already completed, the *same original channel* is kept below so your notes stay consistent. For everything else, I've picked channels that are widely regarded (2024–2026) as the best free English-language resources for that exact subtopic — mostly because English creators genuinely lead in infosec content on YouTube, which you said you're fine with.
#
# ---

# %% [markdown]
# ## ⏱️ How the Time Estimates Work
#
# - Based on **10–15 hrs/week**, consistent effort (matches your original roadmap's pace).
# - Total roadmap: **~2.5 – 3 years** for Stages 1–7 + Purple Team done properly (not rushed, with labs + retention).
# - Times below are **per-stage**, already broken into **per-topic** estimates inside each table.
# - Add **+20% buffer** to every stage if you're also revising older material or preparing notes (you already do this, based on your document).
#
# **Status legend used throughout:** ✅ Completed &nbsp;|&nbsp; 🟡 In Progress &nbsp;|&nbsp; ⬜ Not Started

# %% [markdown]
# ## 🟢 FOUNDATION — Already Completed
# *(Kept in the notebook for tracking & revision — "completed" ≠ "mastered". Revisit if rusty.)*
#
# | # | Topic | Source (same as your original notes) | Status | Suggested Revision Time |
# |---|-------|----------------------------------------|--------|--------------------------|
# | 1 | Networking basics | **Bitten Tech** (YouTube) | ✅ Completed | 3–4 hrs refresher |
# | 2 | Linux basic commands | **M Prashant** (YouTube) | ✅ Completed | 3–4 hrs refresher |
# | 3 | Kali Linux on VirtualBox | Your own setup notes | ✅ Completed | 1 hr sanity check |
# | 4 | Python programming | **Code with Harry** (YouTube) | ✅ Completed | Finish remaining playlist — 15–20 hrs |
#
# **Foundation total (revision + finishing Python): ~1–2 weeks**

# %% [markdown]
# ## 🔵 STAGE 1 — Core Technical Mastery
# **Estimated Stage Duration: 8–10 weeks**
#
# ### Networking Advanced
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | TCP/IP internals, subnetting, routing | **David Bombal** – Networking fundamentals series; **Sunny Classroom** – Subnetting Mastery playlist |✅ Completed   | 12–15 hrs |
# | DNS, HTTP/HTTPS deep understanding | **NetworkChuck** – "How DNS Works", "HTTP/HTTPS Explained" | ✅ Completed   | 4–6 hrs |
# | Wireshark packet analysis | **Skills Insipirstion Academy** - "Wireshark training full course" |  🟡 In Progress| 10–12 hrs |
#
# ### Linux Mastery
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Shell scripting | **freeCodeCamp.org** – "Bash Scripting Full Course" | ⬜ Not Started | 8–10 hrs |
# | Permissions & ACLs | **NetworkChuck** – Linux permissions series | ⬜ Not Started | 3–4 hrs |
# | systemd, cron jobs, log files | **NetworkChuck** Linux series + **The Cyber Mentor** Linux for hackers | ⬜ Not Started | 5–6 hrs |
# | User & group management | **NetworkChuck** Linux series | ⬜ Not Started | 2–3 hrs |
#
# ### Python for Security
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Socket programming | **Tech With Tim** – Python Sockets tutorial | ⬜ Not Started | 4–5 hrs |
# | Automation scripts | **Code with Harry** (continuation — same channel as your in-progress course) | ⬜ Not Started | 6–8 hrs |
# | API interaction | **Corey Schafer** – Python Requests library tutorial | ⬜ Not Started | 3–4 hrs |
# | Basic security tool building | **The Cyber Mentor** – "Python for Ethical Hacking" playlist | ⬜ Not Started | 10–12 hrs |
#
# ### Windows Fundamentals
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Active Directory basics | **John Hammond** – AD fundamentals; **Motasem Hamdan** – AD explained | ⬜ Not Started | 8–10 hrs |
# | PowerShell | **NetworkChuck** – PowerShell for beginners | ⬜ Not Started | 5–6 hrs |
# | Windows internals | **John Hammond** Windows internals videos | ⬜ Not Started | 4–5 hrs |

# %% [markdown]
# **🎓 No paid certification checkpoint yet** — Stage 1 is pure foundation building.
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **Introduction to Cybersecurity** | Cisco Networking Academy / Skills for All | Basic security concepts, threat landscape | 6–8 hrs |
# | **Networking Basics / Networking Essentials badge** | Cisco Skills for All | TCP/IP, subnetting fundamentals | 8–10 hrs |
# | **NSE 1 & NSE 2** | Fortinet Training Institute | Cyber threat landscape, network security fundamentals | 4–5 hrs |
#
# *(All three are genuinely free — training + certificate, no card details needed.)*
#
# ### 🧠 Also This Stage (Don't Skip)
# - **Start a GitHub account today.** Every Python script you write from now on (socket programs, automation tools) goes into a public repo — this is the start of your portfolio.
# - **Start a personal notes wiki** (Notion / Obsidian) — write every networking/Linux/Python concept in your own words as you learn it. This becomes your revision material and blog content later.
#
# ### 📢 What to Post at This Stage
# - **LinkedIn:** A short "Day 1 of my cybersecurity journey" post once you finish Foundation + Stage 1 — state your goal (all-domain practitioner) and roadmap.
# - **GitHub:** Push your first Python security scripts (port scanner, automation tool) with a proper README.
# - **Nothing detailed to blog yet** — Stage 1 is fundamentals; save write-ups for Stage 2 onward when you have real "attacks" to document.
#
# ---

# %% [markdown]
# ## 🔁 REVISION SESSION 1 — After Stage 1 (Foundation + Core Technical)
# *Spaced revision checkpoint — isse skip mat karna, ye wahi step hai jo "padha tha but bhool gaya" trap se bachata hai.*
# **Suggested Time:** 4–5 hrs | **When:** Before starting Stage 2
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# | # | Topic to Revisit | Originally From | Quick Self-Check | Status |
# |---|---|---|---|---|
# | 1 | Networking basics + TCP/IP, subnetting | Foundation + Stage 1 | Can you subnet a /24 on paper without a calculator? | ⬜ Not Started |
# | 2 | Linux commands + permissions/ACLs | Foundation + Stage 1 | Can you chmod/chown + explain rwx in octal from memory? | ⬜ Not Started |
# | 3 | Python basics + socket programming | Foundation + Stage 1 | Can you write a basic port scanner script without looking it up? | ⬜ Not Started |
# | 4 | DNS, HTTP/HTTPS | Stage 1 | Can you explain a DNS lookup + TLS handshake step-by-step out loud? | ⬜ Not Started |
# | 5 | Wireshark packet analysis | Stage 1 | Open a .pcap — can you spot the 3-way handshake in under a minute? | ⬜ Not Started |
# | 6 | Windows fundamentals: AD basics, PowerShell | Stage 1 | Can you name the 3 core AD components (domain, OU, GPO) + 2 PowerShell cmdlets? | ⬜ Not Started |
#
# **Pass check:** If you're stuck on 3+ rows, spend the full 4–5 hrs here before moving on — Stage 2 builds directly on this.
#
# ---

# %% [markdown]
# ## 🔴 STAGE 2 — Offensive Security (Red Team Basics)
# **Estimated Stage Duration: 10–12 weeks**
#
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Reconnaissance: Nmap, Shodan, theHarvester, Recon-ng | **NetworkChuck** – Nmap crash course; **The Cyber Mentor (TCM Security)** – Practical Ethical Hacking, Recon module | ⬜ Not Started | 10–12 hrs |
# | Vulnerability Assessment: Nessus, OpenVAS | **HackerSploit** – Vulnerability Assessment playlist | ⬜ Not Started | 6–8 hrs |
# | Exploitation: Metasploit Framework, Metasploitable practice | **HackerSploit** – Metasploit for Beginners series | ⬜ Not Started | 10–12 hrs |
# | Web App Hacking: Burp Suite, OWASP Top 10 | **Rana Khalil** – OWASP Top 10 + Burp Suite playlist (best structured free series); **PortSwigger** official YouTube for Web Security Academy walkthroughs | ⬜ Not Started | 25–30 hrs |
# | Password Attacks: Hydra, John the Ripper, Hashcat | **HackerSploit** – Password Attacks tutorial | ⬜ Not Started | 5–6 hrs |
# | Active Directory Attacks: Kerberoasting, lateral movement, privesc | **The Cyber Mentor** – "Hacking Active Directory" full course; **Motasem Hamdan** AD attack walkthroughs | ⬜ Not Started | 20–25 hrs |
# | Post-Exploitation: persistence, pivoting | **HackerSploit** – Post Exploitation series | ⬜ Not Started | 6–8 hrs |
#
# **🎓 Certification Checkpoint: eJPT → PJPT** *(both paid)*
# - Study: **TCM Security's PJPT course** (paid, but directly maps to this stage) + **INE's eJPT** free resources
# - **Practice throughout:** TryHackMe (guided rooms) → HackTheBox (once comfortable)
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **Pre-Security & Jr Penetration Tester path certificates** | TryHackMe | Recon, exploitation, web hacking basics | ongoing (per path) |
# | **NSE 3** | Fortinet Training Institute | Threat landscape, network security roles | 2–3 hrs |
# | **Introduction to Ethical Hacking (badge)** | Cisco Skills for All | Ethical hacking fundamentals | 6–8 hrs |
#
# *(These are completion certificates, not proctored exams like eJPT/OSCP — still worth having on LinkedIn as proof of consistent progress.)*
#
# ### 🧠 Also This Stage (Don't Skip)
# - **Legal & ethics awareness — do this FIRST, before touching real-world targets.** Know the exact difference between authorized testing (TryHackMe/HTB/your own lab) and unauthorized access. This is non-negotiable, not optional reading.
# - **Join CTFs** — start with **picoCTF** (beginner-friendly, free, runs periodically) alongside this stage. Compresses weeks of learning into focused sprints.
# - **Start writing box walkthroughs** — after every TryHackMe/HTB machine you solve, write a short report: what you found, how you exploited it, how you'd fix it. This builds the report-writing muscle real pentesters need.
# - **Join community Discords** — TCM Security, TryHackMe, and HackTheBox all have active servers. Real learning happens there too, not just in courses.
#
# ### 📢 What to Post at This Stage
# - **GitHub:** Create a "writeups" repo — one markdown file per TryHackMe/HTB box you complete (redact flags).
# - **LinkedIn:** Post when you finish your first guided TryHackMe room or complete the Pre-Security path — tag it with what you learned, not just "I did X."
# - **Twitter/X or blog:** Short technical threads on specific techniques once you're comfortable (e.g., "How Kerberoasting actually works, explained simply").

# %% [markdown]
# ---

# %% [markdown]
# ## 🔁 REVISION SESSION 2 — After Stage 2 (Offensive Basics)
# *Cumulative revision — thoda Stage 1 bhi chhu lo, mostly Stage 2 pe focus.*
# **Suggested Time:** 5–6 hrs | **When:** Before starting Stage 3
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# | # | Topic to Revisit | Originally From | Quick Self-Check | Status |
# |---|---|---|---|---|
# | 1 | Linux + Python fundamentals (fast pass) | Stage 1 | 10-min speed check — any command/script you're rusty on? | ⬜ Not Started |
# | 2 | Recon: Nmap, Shodan, theHarvester | Stage 2 | Can you run a full Nmap scan + explain every flag you used? | ⬜ Not Started |
# | 3 | Vulnerability scanning: Nessus/OpenVAS | Stage 2 | Can you explain CVSS score meaning without looking it up? | ⬜ Not Started |
# | 4 | Metasploit exploitation basics | Stage 2 | Can you exploit a Metasploitable box from scratch, no walkthrough? | ⬜ Not Started |
# | 5 | OWASP Top 10 + Burp Suite | Stage 2 | Can you name all 10 + demo one (e.g. SQLi) live? | ⬜ Not Started |
# | 6 | Password attacks: Hydra, John, Hashcat | Stage 2 | Can you crack a sample hash with the right tool choice explained? | ⬜ Not Started |
# | 7 | AD attacks: Kerberoasting basics | Stage 2 | Can you explain Kerberoasting in plain language to a non-hacker friend? | ⬜ Not Started |
#
# **Pass check:** Redo one full TryHackMe/HTB box from Stage 2 cold — if it takes noticeably longer than the first time, spend extra hours here.
#
# ---

# %% [markdown]
# ## 🔵 STAGE 3 — Defensive Security / Blue Team
# **Estimated Stage Duration: 8–10 weeks**
#
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | SIEM tools: Splunk, ELK Stack | **Splunk's official YouTube channel** (Splunk Fundamentals) + **Motasem Hamdan** SOC Analyst series | ⬜ Not Started | 15–18 hrs |
# | Log analysis & threat hunting | **13Cubed** (best DFIR/log-analysis channel on YouTube) | ⬜ Not Started | 10–12 hrs |
# | Incident Response process (NIST) | **Professor Messer** – Incident Response videos | ⬜ Not Started | 4–5 hrs |
# | Malware Analysis: static + dynamic, sandboxing | **OALabs** + **John Hammond** malware analysis series | ⬜ Not Started | 15–18 hrs |
# | Digital Forensics: Autopsy, Volatility, disk imaging | **13Cubed** – Autopsy & Volatility playlists (the gold standard channel for this) | ⬜ Not Started | 15–18 hrs |
# | Network Security Monitoring: Snort, Suricata | **David Bombal** – IDS/IPS tutorials | ⬜ Not Started | 6–8 hrs |
#
# **🎓 Certification Checkpoint: Security+ → CySA+** *(both paid, but training is free)*
# - Study: **Professor Messer's free Security+ course** (best free resource, period) → **Professor Messer's CySA+ playlist**
# - **Practice throughout:** TryHackMe SOC Level 1 path, Blue Team Labs Online
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **SOC Level 1 path certificate** | TryHackMe | SIEM, log analysis, IR basics | ongoing (per path) |
# | **Cybersecurity Fundamentals** | IBM SkillsBuild | Security concepts, SOC basics | 8–10 hrs |
# | **CISA Cyber Essentials** | CISA (US gov't) | Risk management, IR fundamentals | 6–8 hrs |
# | **NSE 4 (self-paced track)** | Fortinet Training Institute | Firewall/network defense fundamentals | 6–8 hrs |
#
# ### 🧠 Also This Stage (Don't Skip)
# - **Interview prep starts here.** You now have enough Red + Blue knowledge to be asked real SOC/analyst interview questions — start reviewing common ones even though you're not job-hunting yet.
# - **Burnout check-in.** You're roughly at the halfway point of the mainstream path. Build in a deliberate 1-week rest break if you haven't already — this roadmap only works if you don't quit.
# - **Keep documenting** — SIEM queries, detection logic, and forensics steps you learn go straight into your notes wiki; this becomes genuinely useful reference material on the job later.
#
# ### 📢 What to Post at This Stage
# - **LinkedIn:** Share your Security+ or SOC Level 1 completion — these are strong, recognizable milestones recruiters look for.
# - **GitHub:** A repo of Splunk/ELK detection queries or Sigma rules you've written and tested in your home lab.
# - **Blog/Medium:** A short "how a specific attack looks in the logs" write-up (e.g., Kerberoasting from Stage 2, now viewed from the Blue Team side) — this cross-connects Red and Blue knowledge, which stands out.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔁 REVISION SESSION 3 — After Stage 3 (Defensive / Blue Team)
# *Cumulative — quick touch on Stage 2, deep focus on Stage 3. Red + Blue should start connecting in your head now.*
# **Suggested Time:** 5–6 hrs | **When:** Before starting Stage 4
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# | # | Topic to Revisit | Originally From | Quick Self-Check | Status |
# |---|---|---|---|---|
# | 1 | Recon + exploitation basics (fast pass) | Stage 2 | Could you still run recon → exploit on an easy box unaided? | ⬜ Not Started |
# | 2 | SIEM: Splunk/ELK basics | Stage 3 | Can you write a basic search query from memory? | ⬜ Not Started |
# | 3 | Log analysis & threat hunting | Stage 3 | Given a raw log snippet, can you spot something suspicious? | ⬜ Not Started |
# | 4 | Incident Response (NIST) process | Stage 3 | Can you list all IR phases in order without checking notes? | ⬜ Not Started |
# | 5 | Malware analysis basics | Stage 3 | Can you explain static vs dynamic analysis with an example each? | ⬜ Not Started |
# | 6 | Digital forensics: Autopsy, Volatility | Stage 3 | Can you explain what a memory dump analysis is looking for? | ⬜ Not Started |
#
# **Bonus cross-link exercise:** Pick one attack from Stage 2 (e.g. Kerberoasting) and describe how it would actually show up in Splunk/ELK logs. This is the Red↔Blue connection the roadmap wants you to build.
#
# ---

# %% [markdown]
# ## 🟣 STAGE 4 — Application & Cloud Security
# **Estimated Stage Duration: 6–8 weeks**
#
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Advanced Web/API Security: deserialization, SSRF chains, JWT attacks | **Rana Khalil** advanced modules + **PortSwigger** Web Security Academy | ⬜ Not Started | 12–15 hrs |
# | Mobile App Security: Android/iOS basics, MobSF | **The Cyber Mentor** – Mobile Application Hacking playlist | ⬜ Not Started | 10–12 hrs |
# | Bug Bounty practice | **InsiderPhD** (excellent beginner-to-advanced bug bounty methodology), **NahamSec**, **STÖK** | ⬜ Not Started | ongoing |
# | Cloud Security: AWS/Azure fundamentals, IAM misconfig, cloud pentesting | **freeCodeCamp.org** – AWS Fundamentals; **Tib3rius** – Cloud Penetration Testing playlist | ⬜ Not Started | 15–18 hrs |
# | Container Security: Docker, Kubernetes basics | **TechWorld with Nana** – Docker & Kubernetes crash courses | ⬜ Not Started | 10–12 hrs |
#
# **No mandatory certification here** — this stage feeds directly into bug bounty income potential and cloud pentesting roles. Optional: eWPT / eWPTX if you want a formal web-security cert.
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **AWS Cloud Practitioner Essentials (training badge)** | AWS Skill Builder | Cloud fundamentals — free training, exam itself is paid | 6–8 hrs |
# | **Microsoft SC-900 learning path** | Microsoft Learn | Security, compliance, identity fundamentals — free training, exam paid unless you get a Cloud Skills Challenge voucher | 8–10 hrs |
# | **Introduction to Containers with Docker, Kubernetes & OpenShift (badge)** | IBM SkillsBuild / Coursera audit | Container security basics | 6–8 hrs |
#
# ### 🧠 Also This Stage (Don't Skip)
# - **Start your resume/portfolio properly now.** You have enough range (web, mobile, cloud, containers) to make a genuinely impressive GitHub — organize it, don't just dump scripts.
# - **Bug bounty write-ups** — even practice-lab findings (not real bounties yet) should be documented the way HackerOne reports are structured. This is a skill in itself.
#
# ### 📢 What to Post at This Stage
# - **LinkedIn:** Post about your first bug bounty submission or PortSwigger Academy badge — cloud/web security content gets strong engagement.
# - **GitHub:** A "cloud misconfig" or "container security" mini-project — e.g., a script that scans for common AWS IAM misconfigurations.
# - **Twitter/X:** Follow and engage with the bug bounty community (NahamSec, STÖK, InsiderPhD post live-hacking content) — start commenting with your own findings/questions to get visible.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔁 REVISION SESSION 4 — After Stage 4 (Application & Cloud Security)
# *Cumulative — quick touch on Stage 3, deep focus on Stage 4.*
# **Suggested Time:** 4–5 hrs | **When:** Before starting Stage 5
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# | # | Topic to Revisit | Originally From | Quick Self-Check | Status |
# |---|---|---|---|---|
# | 1 | SIEM + IR basics (fast pass) | Stage 3 | Could you triage a basic alert end-to-end right now? | ⬜ Not Started |
# | 2 | Advanced web/API: SSRF, JWT attacks, deserialization | Stage 4 | Can you explain JWT tampering with a concrete example? | ⬜ Not Started |
# | 3 | Mobile security: MobSF basics | Stage 4 | Can you name 2 common Android app vulns off the top of your head? | ⬜ Not Started |
# | 4 | Cloud security: AWS/Azure IAM misconfigs | Stage 4 | Can you describe a real-world IAM misconfig and its risk? | ⬜ Not Started |
# | 5 | Container security: Docker/Kubernetes | Stage 4 | Can you explain a Docker container escape scenario in plain terms? | ⬜ Not Started |
#
# **Pass check:** Re-attempt one PortSwigger Academy lab from Stage 4 without hints — time yourself against the first attempt.
#
# ---

# %% [markdown]
# ## 🔴 STAGE 5 — Advanced Offensive (Red Team Advanced)
# **Estimated Stage Duration: 12–16 weeks (OSCP-intensity)**
#
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Advanced Active Directory: Golden/Silver tickets, DCSync | **The Cyber Mentor** advanced AD modules; **Motasem Hamdan** deep-dive walkthroughs | ⬜ Not Started | 15–18 hrs |
# | Red Team tactics: C2 frameworks (Cobalt Strike concepts, Sliver) | **IppSec** HTB walkthroughs (uses real C2 concepts); **Black Hills Information Security** webcasts | ⬜ Not Started | 12–15 hrs |
# | Exploit Development basics: buffer overflows | **The Cyber Mentor** – "Buffer Overflow Prep" full course (TryHackMe-aligned); **John Hammond** BOF series | ⬜ Not Started | 15–20 hrs |
# | Reverse Engineering intro: Ghidra, IDA | **Guided Hacking** (best RE-specific channel) + **LiveOverflow** binary exploitation series | ⬜ Not Started | 15–20 hrs |
#
# **🎓 Certification Checkpoint: OSCP** *(paid — no free equivalent exists at this depth)*
# - Core prep: **TCM Security's Practical Ethical Hacking** course as the base, then **IppSec's HackTheBox walkthroughs** (watch after attempting each box yourself)
# - Use the community-maintained **"TJ Null OSCP-like machines"** list on HackTheBox/TryHackMe for realistic practice
# - This is the single most time-intensive stage — budget real lab hours, not just video-watching hours
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **Advanced Red Team path certificates** | TryHackMe | AD attacks, C2 concepts, offensive fundamentals | ongoing (per path) |
# | **HTB Academy free modules (completion badges)** | HackTheBox Academy | Select free modules on AD, web, binary exploitation | varies |
#
# *(At this depth, formal proctored certs are paid — OSCP has no free equivalent. Treat the free path badges as milestones on the way there, not substitutes.)*
#
# ### 🧠 Also This Stage (Don't Skip)
# - **Your GitHub/portfolio should now show depth, not breadth** — pick 2–3 of your best HTB/lab writeups and polish them properly; this is what gets noticed in job applications.
# - **Start following OSCP prep communities** on Discord/Reddit — the exam has quirks (documentation rules, time management) that are best learned from people who've done it recently.
#
# ### 📢 What to Post at This Stage
# - **LinkedIn:** Progress posts on Advanced AD/C2 milestones do well — people respect the visible grind toward OSCP.
# - **Blog:** A deep-dive writeup on one genuinely hard box or exploit-dev exercise — this is prime content for building a technical reputation.
# - **Save the big announcement for later** — don't post "I passed OSCP" content yet; that's the actual certification milestone.

# %% [markdown]
# ### 📘 Optional Deep-Theory Resource (Added)
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | MIT OpenCourseWare 6.858 — Computer Systems Security (Fall 2014, Graduate) | Free MIT OCW lectures + labs (OS security, web security, crypto, exploitation) | ⬜ Not Started | 40–50 hrs |
#
# *Not a prerequisite. Best consumed casually alongside/after Stage 1; taken seriously once Stage 5's buffer overflow / OS security foundation is solid — that's where these lectures pay off most.*
#
# ---

# %% [markdown]
# ## 🔁 REVISION SESSION 5 — After Stage 5 (Advanced Offensive)
# *Cumulative — quick touch on Stage 4, deep focus on Stage 5. This stage is OSCP-intensity, so revision matters more here, not less.*
# **Suggested Time:** 6–8 hrs | **When:** Before starting Stage 6 (GRC)
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# | # | Topic to Revisit | Originally From | Quick Self-Check | Status |
# |---|---|---|---|---|
# | 1 | Cloud + container security (fast pass) | Stage 4 | Could you still spot an obvious IAM/container misconfig? | ⬜ Not Started |
# | 2 | Advanced AD: Golden/Silver tickets, DCSync | Stage 5 | Can you explain the difference between Golden and Silver ticket attacks? | ⬜ Not Started |
# | 3 | C2 framework concepts | Stage 5 | Can you explain what a C2 beacon is and why detection is hard? | ⬜ Not Started |
# | 4 | Buffer overflow basics | Stage 5 | Can you walk through a basic BOF exploit dev process step-by-step? | ⬜ Not Started |
# | 5 | Reverse engineering intro: Ghidra | Stage 5 | Can you open a binary in Ghidra and identify the main function? | ⬜ Not Started |
#
# **Pass check:** Redo one full TJ Null OSCP-like box end-to-end, untimed but unaided. This is your real signal of readiness, not just re-reading notes.
#
# ---

# %% [markdown]
# ## ⚪ STAGE 6 — Governance, Risk & Compliance (GRC)
# *Runs parallel/ongoing alongside other stages — important for career growth, less hands-on technical.*
# **Estimated concentrated study time: 4–6 weeks (spread across the whole roadmap)**
#
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Frameworks: ISO 27001, NIST, MITRE ATT&CK | **Simplilearn** – GRC full course; **MITRE ATT&CK's official YouTube channel** for framework fundamentals | ⬜ Not Started | 10–12 hrs |
# | Risk assessment basics | **Simplilearn** / **Cybrary** GRC modules | ⬜ Not Started | 4–5 hrs |
# | Security policies & compliance awareness | **Cybrary** – Governance & Compliance path | ⬜ Not Started | 4–5 hrs |
#
# **No dedicated paid certification required at this stage** — GRC knowledge feeds into your Stage 7 choice and long-term career (CISSP/CISM become relevant only after 5+ years' experience — future consideration, not now).
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **Understanding MITRE ATT&CK (badge)** | MITRE ATT&CK training resources | Framework fundamentals | 4–5 hrs |
# | **GRC Fundamentals** | Simplilearn / Cybrary free courses | ISO 27001, NIST, risk basics | 6–8 hrs |
# | **CISA Cyber Essentials** | CISA (US gov't) | Governance & risk fundamentals (if not already done in Stage 3) | 6–8 hrs |
#
# ### 🧠 Also This Stage (Don't Skip)
# - **This is a good checkpoint to review your whole documentation habit** — go back through your notes wiki and clean it up; GRC knowledge ties everything else together conceptually.
#
# ### 📢 What to Post at This Stage
# - **LinkedIn:** A "connecting the dots" post — how GRC frameworks (NIST, MITRE ATT&CK) relate to the hands-on Red/Blue work you've already done. This shows maturity beyond pure technical skill, which recruiters notice.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔁 REVISION SESSION 6 — After Stage 6 (GRC)
# *Cumulative — quick touch on Stage 5, deep focus on GRC frameworks. Short session — GRC is conceptual, not hands-on.*
# **Suggested Time:** 2–3 hrs | **When:** Before starting Stage 7
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# | # | Topic to Revisit | Originally From | Quick Self-Check | Status |
# |---|---|---|---|---|
# | 1 | Advanced AD / exploit dev (fast pass) | Stage 5 | Could you still explain a Golden Ticket attack in one paragraph? | ⬜ Not Started |
# | 2 | Frameworks: ISO 27001, NIST, MITRE ATT&CK | Stage 6 | Can you map one Stage 2/5 attack technique to a MITRE ATT&CK ID? | ⬜ Not Started |
# | 3 | Risk assessment basics | Stage 6 | Can you explain likelihood × impact risk scoring in your own words? | ⬜ Not Started |
# | 4 | Security policies & compliance | Stage 6 | Can you name the difference between a policy, standard, and procedure? | ⬜ Not Started |
#
# **Cross-link exercise:** Take any one attack technique you learned in Stage 2 or Stage 5 and find its actual MITRE ATT&CK technique ID. This ties your hands-on skills to the framework language recruiters and GRC roles speak.
#
# ---

# %% [markdown]
# ## 🟡 STAGE 7 — Specialization Deep-Dive
# *By this point you'll know which domain feels strongest. Go deep in ONE.*
# **Estimated Stage Duration: 12–16 weeks**
#
# | Path | Best Source | Status | Est. Time |
# |---|---|---|---|
# | **Offensive** → Advanced OSCP/OSCE | **IppSec** advanced walkthroughs; **Guided Hacking** for exploit-heavy OSCE prep | ⬜ Not Started | 40–60 hrs |
# | **Defensive/Forensics** → GCIH/GCFA | **13Cubed** (still the best forensics channel); **SANS** free webcasts | ⬜ Not Started | 40–60 hrs |
# | **Bug Bounty** → Top researcher path | **NahamSec**, **InsiderPhD**, **STÖK** live hacking sessions | ⬜ Not Started | ongoing/40+ hrs |
#
# **🎓 Certification Checkpoint: OSCE / GCIH / GCFA** *(all paid — this is the advanced specialization stage, free options run out here)*
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **HTB Academy specialization modules (free tier badges)** | HackTheBox Academy | Path-specific advanced modules | varies |
# | **SANS free webcasts + completion certificates** | SANS Institute | Forensics/IR deep dives (if Defensive path chosen) | varies |
#
# ### 🧠 Also This Stage (Don't Skip)
# - **This is when your job search / freelance bug bounty income realistically starts.** Update your resume and portfolio to reflect your chosen specialization clearly — don't present yourself as "does everything," present as "expert in X, competent in everything else."
# - **Interview prep intensifies here** — mock interviews specific to your chosen path (pentester, forensics analyst, or bug bounty hunter).
#
# ### 📢 What to Post at This Stage
# - **LinkedIn:** Announce your specialization publicly — "Going deep into [offensive/forensics/bug bounty]" — this is when recruiters and peers start reaching out.
# - **Blog/portfolio site:** Time to build a proper personal site (even a simple GitHub Pages one) consolidating your best writeups — this becomes your professional calling card.

# %% [markdown]
# ---

# %% [markdown]
# ## 🏆 FINAL MASTER REVISION — Full Roadmap Recap (After Stage 7)
# *Ye sabse important session hai. Poora roadmap ek baar top-to-bottom touch karo — iska maqsad ye hai ki jab koi bhi topic pooche, jaise aaj hi padha ho waisa laga.*
# **Suggested Time:** 1 full week (spread across days, ~2–3 hrs/day) | **When:** After finishing Stage 7, before specializing further / job hunting
#
# *(Method for every revision session below — don't just re-read, actually test yourself)*
# 1. **Recall first, notes second** — close everything, write/say what you remember about each topic for 2–3 min. THEN check notes for gaps.
# 2. **Re-watch only the weak spots** — not the whole playlist again, just the 1–2 sub-topics that didn't come back to you.
# 3. **Redo ONE hands-on thing** — one command, one script, one lab box, one config — from that stage, from scratch, no copy-paste.
#
# **Format for this one:** don't redo hands-on labs for everything — that would take months. Instead, for each stage below, do a **5–10 min spoken/written recall** ("if someone asked me to explain this stage in an interview, what would I say") and only dive deeper where you freeze.
#
# | # | Stage | Core Topics to Recall Out Loud | Status |
# |---|---|---|---|
# | 1 | Foundation | Networking basics, Linux commands, Python fundamentals | ⬜ Not Started |
# | 2 | Stage 1 — Core Technical | TCP/IP, DNS/HTTP, Wireshark, shell scripting, AD basics, PowerShell | ⬜ Not Started |
# | 3 | Stage 2 — Offensive Basics | Recon, vuln scanning, Metasploit, OWASP Top 10, password attacks, Kerberoasting | ⬜ Not Started |
# | 4 | Stage 3 — Defensive/Blue Team | SIEM, log analysis, IR process, malware analysis, forensics | ⬜ Not Started |
# | 5 | Stage 4 — App & Cloud Security | SSRF/JWT attacks, mobile security, cloud IAM, container security | ⬜ Not Started |
# | 6 | Stage 5 — Advanced Offensive | Golden/Silver tickets, C2 concepts, buffer overflows, reverse engineering | ⬜ Not Started |
# | 7 | Stage 6 — GRC | ISO 27001, NIST, MITRE ATT&CK, risk assessment | ⬜ Not Started |
# | 8 | Stage 7 — Specialization | Your chosen deep-dive path (Offensive / Forensics / Bug Bounty) | ⬜ Not Started |
#
# **Real test of mastery:** Pick 3 random topics from across different stages (not your specialization) and explain each to someone non-technical in under 2 minutes. If you can do that for topics from Stage 1 as easily as Stage 7, the spaced revision worked — the whole roadmap is genuinely "live" in your head, not just the recent stuff.
#
# **After this:** you're ready for Purple Teaming / Advanced-Niche domains / job applications with the confidence that nothing from the earlier stages has quietly evaporated.
#
# ---

# %% [markdown]
# ## 🟪 PURPLE TEAMING — Bridge Role (Post Stage 7)
# *Not a separate technical domain — a collaboration function between Red and Blue. Requires solid hands-on experience in both Stage 2/5 (offense) and Stage 3 (defense) before this becomes realistic.*
# **Estimated Stage Duration: 6–8 weeks**
#
# ### Core Concepts
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | MITRE ATT&CK Framework (TTPs) | **MITRE ATT&CK official channel** + **Black Hills Information Security** ATT&CK webcasts | ⬜ Not Started | 6–8 hrs |
# | Attack Simulation | **Black Hills Information Security** – Purple Team webcasts | ⬜ Not Started | 6–8 hrs |
# | Detection Engineering (SIEM rules/alerts) | **13Cubed** + **Black Hills Information Security** | ⬜ Not Started | 8–10 hrs |
# | Threat Intelligence mapping (APT TTPs) | **13Cubed**; MITRE ATT&CK Groups database walkthroughs | ⬜ Not Started | 6–8 hrs |
#
# ### Hands-on Skills
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Purple Team exercises (attack → detect → improve) | **Black Hills Information Security** Purple Team playlist | ⬜ Not Started | 10–12 hrs |
# | Caldera (MITRE's tool) | **MITRE official Caldera documentation/YouTube demos** | ⬜ Not Started | 4–5 hrs |
# | Atomic Red Team | **Red Canary official YouTube** – Atomic Red Team intro | ⬜ Not Started | 4–5 hrs |
# | Log analysis of specific attacks (e.g. Kerberoasting) | **13Cubed** | ⬜ Not Started | 6–8 hrs |
#
# ### Process Knowledge
# | Topic | Best Source | Status | Est. Time |
# |---|---|---|---|
# | Gap analysis | **Black Hills Information Security** | ⬜ Not Started | 3–4 hrs |
# | Reporting to technical & management audiences | **SANS** free reporting webcasts | ⬜ Not Started | 3–4 hrs |
# | Continuous feedback loop | Practical — built through repetition, not videos | ⬜ Not Started | ongoing |
#
# ### Practical Path
# 1. Solidify Stage 2 (Red) and Stage 3 (Blue) — prerequisite, not optional.
# 2. Get familiar with the **MITRE ATT&CK Navigator** tool.
# 3. In your home lab: run an attack with Atomic Red Team → detect it in Splunk/ELK → tune the rule.
#
# ### 🎁 Free Certificates You Can Earn in This Stage
# | Free Certificate | Provider | Covers | Time |
# |---|---|---|---|
# | **ATT&CK Defender / Purple Team fundamentals resources** | MITRE / Red Canary official material | ATT&CK-based detection & simulation | varies |
#
# *(Purple Teaming is more of a practiced skill than a certified one — most of your credibility here comes from documented home-lab exercises, not badges.)*
#
# ### 🧠 Also This Stage (Don't Skip)
# - This is where your **continuous feedback loop habit** (attack → detect → improve → repeat) becomes a permanent part of how you work, not just a roadmap topic.
#
# ### 📢 What to Post at This Stage
# - **Blog/GitHub:** Document full purple-team exercises — "I ran Atomic Red Team technique X, here's what showed (and didn't show) in Splunk, here's the rule I wrote to fix it." This is genuinely rare, high-value content.
# - **LinkedIn:** This is a strong "I bridge Red and Blue" positioning post — very few candidates can credibly claim this.

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 ADVANCED / NICHE DOMAINS (Beyond Mainstream Path)
# *Highly specialized areas most professionals only enter after their core foundation is strong — driven by specific interest or job requirement. **Not required** for a complete cybersecurity career.*
#
# | Domain | Topics | Best Source | Status | Est. Time (if pursued) |
# |---|---|---|---|---|
# | **IoT Security** | Firmware analysis, MQTT/Zigbee/BLE, Firmwalker, Binwalk | **The Cyber Mentor** IoT hacking content; **Hak5** device-hacking demos | ⬜ Not Started | 15–20 hrs |
# | **OT / ICS Security** | SCADA, power/factory infra, Modbus, DNP3 | **SANS ICS official YouTube**; **Dragos** webinars | ⬜ Not Started | 15–20 hrs |
# | **Hardware Hacking** | Chip-level attacks, JTAG/UART, Bus Pirate, ChipWhisperer | **GreatScott!** (hardware fundamentals); **Joe Grand (Kingpin)** conference talks | ⬜ Not Started | 20–25 hrs |
# | **Advanced Cryptography Research** | Algorithm design, applied crypto, PKI, cryptanalysis | **Computerphile** (crypto series); MIT OCW crypto lectures | ⬜ Not Started | 25–30 hrs |
# | **Blockchain / Web3 Security** | Smart contract auditing (Solidity), Slither, MythX, DeFi exploits | **Smart Contract Programmer**; **Secureum** bootcamp videos | ⬜ Not Started | 20–25 hrs |
# | **Exploit Development / 0-day Research** | Deep binary exploitation, fuzzing (AFL, libFuzzer), CVE reporting | **LiveOverflow** (best channel for this exact niche); **Guided Hacking** | ⬜ Not Started | 30–40 hrs |
#
# *Explore only if genuine interest develops during Stages 1–7, or a specific job path demands it.*
#
# ---

# %% [markdown]
# ## 🧪 PRACTICE PLATFORMS (Use Throughout — Not Stage-Locked)
#
# | Platform | Best For | Status | Notes |
# |---|---|---|---|
# | **TryHackMe** | Structured, beginner-friendly guided labs | ⬜ Not Started | Start here for every new topic |
# | **HackTheBox** | Intermediate–advanced real-world machines | ⬜ Not Started | Move here once TryHackMe feels easy |
# | **PortSwigger Web Security Academy** | Deep, free web security labs | ⬜ Not Started | Mandatory for Stage 2 & 4 web topics |
# | **Blue Team Labs Online** | Defensive practice | ⬜ Not Started | Pairs with Stage 3 |
# | **HackerOne / Bugcrowd** | Real bug bounty reports & practice | ⬜ Not Started | Stage 4 onward |
# | **MIT OCW 6.858** | Computer Systems Security lectures | ⬜ Not Started | Optional theory depth |
#
# ---

# %% [markdown]
# ## 🏅 CERTIFICATION PATH (Staged Order) — When to Get What
#
# ### Main paid certifications (the industry-recognized backbone)
# | Stage | Certification | Type | Cost | Status | Why here |
# |---|---|---|---|---|---|
# | Stage 1 (end) | **CompTIA Security+** | Foundational, vendor-neutral | 💰 Paid exam (~$400), free study material | ⬜ Not Started | Confirms core knowledge before going offensive |
# | Stage 2 (end) | **eJPT → PJPT** | Junior Pentester | 💰 Paid | ⬜ Not Started | Validates hands-on red-team basics |
# | Stage 3 (end) | **CompTIA CySA+** | Blue Team / Analyst | 💰 Paid exam (~$400), free study material | ⬜ Not Started | Confirms SOC/analyst-level defensive skill |
# | Stage 5 (end) | **OSCP** | Advanced Offensive — industry gold standard | 💰 Paid | ⬜ Not Started | The single most respected practical cert in offensive security |
# | Stage 7 (end) | **GCIH / GCFA / OSCE** | Advanced specialization | 💰 Paid | ⬜ Not Started | Whichever matches the domain you chose to go deep in |
#
# > 💡 **Rule of thumb:** never chase a certification before the stage that builds the skills it tests — cert-first, skill-later leads to paper-certified professionals who can't perform in real environments. Your roadmap avoids this trap by design.
#
# ### 🎁 All Free Certificates Across the Whole Roadmap (consolidated)
# *(Full details are inside each stage above — this is just the quick-reference index.)*
#
# | Stage | Free Certificate | Provider |
# |---|---|---|
# | Stage 1 | Introduction to Cybersecurity | Cisco Networking Academy |
# | Stage 1 | Networking Basics badge | Cisco Skills for All |
# | Stage 1 | NSE 1 & 2 | Fortinet Training Institute |
# | Stage 2 | Pre-Security & Jr Penetration Tester path certs | TryHackMe |
# | Stage 2 | NSE 3 | Fortinet Training Institute |
# | Stage 2 | Introduction to Ethical Hacking badge | Cisco Skills for All |
# | Stage 3 | SOC Level 1 path cert | TryHackMe |
# | Stage 3 | Cybersecurity Fundamentals | IBM SkillsBuild |
# | Stage 3 | Cyber Essentials | CISA |
# | Stage 3 | NSE 4 (self-paced) | Fortinet Training Institute |
# | Stage 4 | Cloud Practitioner Essentials (training) | AWS Skill Builder |
# | Stage 4 | SC-900 learning path (training) | Microsoft Learn |
# | Stage 4 | Containers with Docker/Kubernetes badge | IBM SkillsBuild |
# | Stage 5 | Advanced Red Team path certs | TryHackMe |
# | Stage 5 | HTB Academy free module badges | HackTheBox Academy |
# | Stage 6 | Understanding MITRE ATT&CK badge | MITRE |
# | Stage 6 | GRC Fundamentals | Simplilearn / Cybrary |
# | Stage 7 | HTB Academy specialization badges | HackTheBox Academy |
# | Stage 7 | SANS webcast certificates | SANS Institute |
#
# > ⚠️ **Note on ISC2 Certified in Cybersecurity (CC):** this used to be the single best free cert available, but ISC2's free-voucher program (*One Million Certified in Cybersecurity*) closed to new sign-ups on **May 20, 2026**. It's now a paid exam (~$199 + $50/yr maintenance) for new candidates — mentioned here so you don't chase outdated "free CC" advice you might find online.
#
# ---

# %% [markdown]
# ## 🧠 Things That Are Now Built Into Each Stage (Quick Index)
#
# You said you'd forgotten a few things — they're now woven directly into the relevant stage above (look for the **🧠 Also This Stage** and **📢 What to Post** sections). Quick index of where each one lives:
#
# | Habit | Now Found In |
# |---|---|
# | Soft skills & report writing | Stage 2 |
# | Home Lab Documentation Habit | Stage 1 (start), reinforced Stage 3 & 6 |
# | Networking with the community (Discord/Twitter) | Stage 2 |
# | CTFs (picoCTF etc.) | Stage 2 |
# | Resume/portfolio (GitHub) building | Stage 1 (start), Stage 4 (properly organized), Stage 7 (polished) |
# | Burnout management | Stage 3 (halfway checkpoint) |
# | Legal & ethics awareness | Stage 2 (before touching real targets) |
# | Interview prep | Stage 3 (starts), Stage 7 (intensifies) |
# | LinkedIn presence | Every stage from Stage 1 onward — each has its own "What to Post" ideas |
#
# ---

# %% [markdown]
# ## 🎯 Reality Check
#
# Even 20-year industry veterans don't know every domain deeply. This roadmap covers the **complete mainstream path (Stages 1–7 + Purple Team)**, which makes you a strong, multi-domain professional — genuinely rare in the industry. Niche domains are **bonus territory**, not requirements.
#
# **Estimated total timeline: 2–3 years at 10–15 hrs/week, consistent effort.**

# %% [markdown]
# ---
# ### 🚀 Final Note
# This notebook is meant to grow with you. Add new rows, new resources, and personal notes directly into the markdown cells as you go — turn this into *your* master reference, not just a static plan. Good luck on the journey to becoming an all-domain cybersecurity practitioner. 🛡️
